# %% [markdown]
# # diabetes project

# %% [markdown]
# # imported lib

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.metrics import mean_squared_error , r2_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import numpy as np

# %% [markdown]
# # load, split, clean the data

# %%
df = pd.read_csv('https://raw.githubusercontent.com/hanalareina29/Diabetes.csv/refs/heads/main/diabetes.csv')

#remove rows that contain zero in this coloumns
columns = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']
df = df.loc[(df[columns] != 0).all(axis=1)]

## re split after cleaning
y = df['Outcome']
x = df.drop('Outcome', axis=1)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=10)

# %% [markdown]
# ## datd info

# %%
print(df.shape)
print(df.info())
df.describe()
# Out:
# (392, 9)
# <class 'pandas.core.frame.DataFrame'>
# Index: 392 entries, 3 to 765
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               392 non-null    int64
#  1   Glucose                   392 non-null    int64
#  2   BloodPressure             392 non-null    int64
#  3   SkinThickness             392 non-null    int64
#  4   Insulin                   392 non-null    int64
#  5   BMI                       392 non-null    float64
#  6   DiabetesPedigreeFunction  392 non-null    float64
#  7   Age                       392 non-null    int64
#  8   Outcome                   392 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 30.6 KB
# None
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   392.000000  392.000000     392.000000     392.000000  392.000000
# ...

# %% [markdown]
# # Feature scalling or standersation

# %%
scaler= StandardScaler()

x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %% [markdown]
# # bulding model

# %% [markdown]
# ## training model

# %%
logr = LogisticRegression()
logr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ## applying model

# %%
y_logr_train_pred = logr.predict(x_train)
y_logr_test_pred = logr.predict(x_test)

# %% [markdown]
# ## evaluate model

# %%
logr_train_mse = mean_squared_error(y_train, y_logr_train_pred)
logr_train_r2 = r2_score(y_train , y_logr_train_pred)

logr_test_mse = mean_squared_error(y_test, y_logr_test_pred)
logr_test_r2 = r2_score(y_test , y_logr_test_pred)

logr_results = pd.DataFrame(['LogisticRegression' 
, logr_train_mse , logr_train_r2, logr_test_mse ,logr_test_r2]).transpose()
logr_results.columns = ['methods', 'training mse', 'training r2', 'test mse', 'test r2']
logr_results
# Out:
#               methods training mse training r2  test mse   test r2
# 0  LogisticRegression     0.210863    0.062789  0.253165 -0.226708

# %% [markdown]
# # test

# %%
x_train_prediction = logr.predict(x_train)
training_data_accuracy = accuracy_score(x_train_prediction, y_train)

print('Accuracy score of the training data : ', training_data_accuracy)
# Out:
# Accuracy score of the training data :  0.7891373801916933

# %%
input_data = (1,90,66,23,94,28.1,0.167,21)

# changing the input_data to numpy array
input_data_nparray = np.asarray(input_data)

# reshape the array as we are predicting for one instance
input_data_reshaped = input_data_nparray.reshape(1,-1)

# standardize the input data
std_data = scaler.transform(input_data_reshaped)
print(std_data)

prediction = logr.predict(std_data)

if (prediction[0] == 0):
  print('The person is not diabetic')
else:
  print('The person is diabetic')
# Out:
# [[-0.71038668 -1.07643893 -0.35543382 -0.57604733 -0.53461054 -0.7105676
#   -1.04886421 -0.96592407]]
# The person is not diabetic
# D:\program\anaconda\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
